# %%
#7 Task 1
import matplotlib.pyplot as plt

temperatures = [8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5,
16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 13.4, 8.1,
17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7, 7.8, 17.5, 13.6, 8.7,
17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8,
16.6, 12.5]

cold_temp =[]
mild_temp =[]
comfort_temp =[]

for temp in temperatures:
    if temp<10 :
        cold_temp.append(temp)
    elif 10<=temp<15 :
        mild_temp.append(temp)
    else:
        comfort_temp.append(temp)

    

print("cold temperature:",cold_temp)
print("mild temperature",mild_temp)
print("comfort temperature",comfort_temp)

#Task 2
print("Times it was cold temperature:",len(cold_temp))
print("Times it was mild temperature",len(mild_temp))
print("Times it was comfort temperature",len(comfort_temp))

#Task 3
fahrenheit =[(temp * 9/5)+32 for temp in temperatures]
print("temperature in fahrenheit",fahrenheit)

#Task 4
night_temp = []
day_temp = []
evening_temp = []

for temp in temperatures:
    if temp<9 :
        night_temp.append(temp)
    elif 8<=temp<16  :
        evening_temp.append(temp)
    else:
        day_temp.append(temp)

print("Night temperature :",night_temp)
print("Day temperature:",day_temp)
print("Evening temperature",evening_temp)

av_night_temp = sum(night_temp)/len(night_temp)
print("Average night temperature",av_night_temp)


days = list(range(1, len(temperatures) + 1))

plt.figure(figsize=(12, 8))
plt.plot(days, temperatures, marker='o', linestyle='-', color='red', label='Temperature (°C)')


plt.title("Day vs. Temperature", fontsize=16)
plt.xlabel("Day", fontsize=14)
plt.ylabel("Temperature (°C)", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)


plt.tight_layout()
plt.show()
# Out:
# cold temperature: [8.2, 7.9, 9.0, 8.5, 7.7, 8.4, 9.5, 8.1, 7.6, 8.0, 7.8, 8.7, 9.2, 8.3, 8.9, 7.8]
# mild temperature [14.1, 13.5, 13.0, 12.9, 13.3, 14.0, 13.4, 14.2, 12.8, 13.7, 13.6, 13.8, 13.9, 12.7, 13.1, 12.5]
# comfort temperature [17.4, 18.0, 17.8, 16.5, 17.2, 16.7, 18.3, 17.9, 17.0, 16.8, 17.5, 17.1, 18.1, 16.4, 18.2, 16.6]
# Times it was cold temperature: 16
# Times it was mild temperature 16
# Times it was comfort temperature 16
# temperature in fahrenheit [46.76, 63.32, 57.379999999999995, 46.22, 64.4, 56.3, 48.2, 64.04, 55.4, 47.3, 61.7, 55.22, 45.86, 62.959999999999994, 55.94, 47.120000000000005, 62.059999999999995, 57.2, 49.1, 64.94, 56.120000000000005, 46.58, 64.22, 57.56, 45.68, 62.6, 55.04, 46.4, 62.24, 56.66, 46.04, 63.5, 56.48, 47.66, 62.78, 56.84, 48.56, 64.58, 57.02, 46.94, 61.519999999999996, 54.86, 48.02, 64.75999999999999, 55.58, 46.04, 61.88, 54.5]
# Night temperature : [8.2, 7.9, 8.5, 7.7, 8.4, 8.1, 7.6, 8.0, 7.8, 8.7, 8.3, 8.9, 7.8]
# ...

# %%
#8 Task 1

def sum_nested_list(nested_list):
    total = 0
    for item in nested_list:
        if isinstance(item, list):  
            total += sum_nested_list(item)
        else:  
            total += item
    return total


nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]


result = sum_nested_list(nested_list)
print("The total sum of all numbers in the nested list is:", result)
# Out:
# The total sum of all numbers in the nested list is: 36

# %%
#Task 2
def generate_permutations(s):
    
    if len(s) <= 1:
        return [s]
    
    # Recursive case
    permutations = set()  
    for i, char in enumerate(s):
       
        remaining = s[:i] + s[i+1:]
        for perm in generate_permutations(remaining):
            
            permutations.add(char + perm)
    
    return list(permutations)  


print(generate_permutations("abc"))  
print(generate_permutations("aab"))

# %%
#Task 3
def calculate_directory_size(directory):
    
    total_size = 0
    
    for name, value in directory.items():
        if isinstance(value, dict):  # If value is a dictionary, it's a subdirectory
            total_size += calculate_directory_size(value)
        else:  # Otherwise, it's a file
            total_size += value

    return total_size


directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 400,
        "file4.txt": 100
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 250
        },
        "file6.txt": 150
    }
}


print(f"Total size: {calculate_directory_size(directory_structure)} KB")
# Out:
# Total size: 1400 KB

# %%
#8.1 Task 1 
def min_coins(coins, amount):
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0
    for coin in coins:
      for i in range(coin, amount + 1):
        dp[i] = min(dp[i], dp[i - coin] + 1)
    return dp[amount] if dp[amount] != float('inf') else -1

coins = [1, 2, 5]
amount = 11
result = min_coins(coins, amount)

print(f"Minimum coins to make {amount}: {result}")
# Out:
# Minimum coins to make 11: 3

# %%
#Task 2 

def longest_common_subsequence(s1, s2):
    
    m, n = len(s1), len(s2)
    dp = [[0] * (n + 1) for _ in range(m + 1)]

    
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1  
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])  

    
    return dp[m][n]


s1 = "abcde"
s2 = "ace"
result = longest_common_subsequence(s1, s2)

print(f"Length of LCS between '{s1}' and '{s2}': {result}")
# Out:
# Length of LCS between 'abcde' and 'ace': 3

# %%
#Task 3

def knapsack(weights, values, capacity):
    
    n = len(weights)
    dp = [[0] * (capacity + 1) for _ in range(n + 1)]

   
    for i in range(1, n + 1):
        for w in range(1, capacity + 1):
            if weights[i - 1] <= w:
                dp[i][w] = max(dp[i - 1][w], dp[i - 1][w - weights[i - 1]] + values[i - 1])
            else:
                dp[i][w] = dp[i - 1][w]

   
    return dp[n][capacity]


weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7
result = knapsack(weights, values, capacity)

print(f"Maximum value achievable: {result}")
# Out:
# Maximum value achievable: 9
